# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Matplotlib
# pip install matplotlib
#
# https://matplotlib.org/tutorials/introductory/pyplot.html

# %%
import matplotlib.pyplot as plt

# %%
#Forma expres de graficar

x = [3, 4, 5, 6]
y = [5, 7, 8, 2]
plt.plot(x, y)

# %%
x_2 = [3, 4, 5, 6]
y_2 = [2, 5, 3, 6]
plt.bar(x_2, y_2)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.scatter(x = x, y = y, label = "1")
plt.scatter(x_2, y_2, label = "2")
plt.legend()

# %% [markdown]
# #### Conozcamos las variables dentro de los graficos

# %%
plt.figure(figsize=(8,4))
plt.plot(x, y, label = "linea 1")
plt.plot(x_2, y_2, label = "linea 2")
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.legend(loc = "best", fontsize="12")
plt.show()
plt.close()

# %%
#Creamos una DF de ejemplo para graficar
df_ejemplo = pd.DataFrame(data = [[1, 5, 100, "red"],[2, 6, 200, "red"], [3, 2, 300, "blue"], [4, 3, 400, "blue"]],
                          columns = ["x", "y", "size", "color"])
df_ejemplo
# Out:
#    x  y  size color
# 0  1  5   100   red
# 1  2  6   200   red
# 2  3  2   300  blue
# 3  4  3   400  blue

# %%
plt.scatter(x = "x", y = "y", s="size", c="color", data = df_ejemplo, label = "puntos")
plt.legend()
plt.savefig("outputs\\fig_ejemplo.png")
plt.show()

# %% [markdown]
# ## Grafiquemos algo real

# %%
#El excel "league_winner" contiene la cantidad de veces que el resultado de los partidos de cada liga en la primera columna
#fue ganador local, ganador visita o empate

df_league_winner = pd.read_excel("inputs\\league_winner.xlsx")
df_league_winner.head(), df_league_winner.columns, df_league_winner.shape, df_league_winner.describe()
# Out:
# (         league  winner  partidos
#  0  Bundesliga 1  empate       145
#  1  Bundesliga 1   local       254
#  2  Bundesliga 1  visita       215
#  3  Bundesliga 2  empate       271
#  4  Bundesliga 2   local       378,
#  Index(['league', 'winner', 'partidos'], dtype='object'),
#  (27, 3),
#           partidos
#  count   27.000000
#  mean   345.814815
#  std    118.204203
#  min    145.000000
#  25%    261.500000
#  50%    318.000000
#  75%    420.000000
#  max    683.000000)

# %% [markdown]
# # Seaborn
# pip install seaborn
#
# https://seaborn.pydata.org/tutorial.html
#
# Seaborn es una libreria basada en matplotlib

# %%
import seaborn as sns

# %%
#Grafiquemos la distribucion de resultados para la Bundesliga 1

league = "Bundesliga 1"
df_bundesliga1 = df_league_winner.loc[df_league_winner["league"] == league]

plt.figure(figsize=(10,5))
sns.barplot(data = df_bundesliga1, x = "winner", y = "partidos")
plt.show()

# %%
#Ahora graficamos la distribucion para cada una de las ligas

plt.figure(figsize=(20,5))
sns.barplot(data = df_league_winner, x = "league", y = "partidos", hue = "winner")
plt.show()

# %% [markdown]
# # Plotly
# pip install plotly
# pip install plotly-express
#
# https://plotly.com/python/plotly-fundamentals/
#
# Con Plotly y Plotly express podemos generar graficos en formato html

# %%
import plotly.graph_objects as go
import plotly_express as px

# %% [markdown]
# ### Un poco de Plotly express
#
# --Plotly express esta especialmente desarrollado para trabajar con pandas
#
# https://plotly.com/python/plotly-express/

# %%
px.bar(data_frame = df_league_winner, x = "league", y = "partidos", color = "winner")
# Out:
# <div>
#
#
#             <div id="bc88014a-9c36-48c9-816d-949688114561" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bc88014a-9c36-48c9-816d-949688114561")) {
#                     Plotly.newPlot(
#                         'bc88014a-9c36-48c9-816d-949688114561',
# ...

# %%
px.line(df_league_winner, x = "league", y = "partidos", color = "winner")
# Out:
# <div>
#
#
#             <div id="ad8a8947-33aa-4ee3-8c94-28516afcb0c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ad8a8947-33aa-4ee3-8c94-28516afcb0c6")) {
#                     Plotly.newPlot(
#                         'ad8a8947-33aa-4ee3-8c94-28516afcb0c6',
# ...

# %% [markdown]
# ### Figura 3D con Plotly express

# %%
#Primero pasamos "local, empate, visita" como columnas
#pandas pivot: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pivot.html

df_3d = df_league_winner.pivot(columns = "winner", values = "partidos", index = "league")
print(df_3d)
df_3d = df_3d.reset_index()
df_3d
# Out:
# winner            empate  local  visita
# league
# Bundesliga 1         145    254     215
# Bundesliga 2         271    378     260
# Championship         453    683     482
# Premier League       260    495     345
# Primeira Liga        197    399     291
# Primera Division     299    491     318
# Segunda Division     293    377     227
# Serie A              263    441     366
# Serie B              369    484     281
# winner            league  empate  local  visita
# 0           Bundesliga 1     145    254     215
# 1           Bundesliga 2     271    378     260
# 2           Championship     453    683     482
# 3         Premier League     260    495     345
# 4          Primeira Liga     197    399     291
# 5       Primera Division     299    491     318
# 6       Segunda Division     293    377     227
# 7                Serie A     263    441     366
# 8                Serie B     369    484     281

# %%
figura_3d = px.scatter_3d(df_3d, x="local", y="visita", z="empate", text = "league")
figura_3d.update_traces(mode = "markers")
# Out:
# <div>
#
#
#             <div id="923b0b7e-349f-48ed-afb4-571043c3a759" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("923b0b7e-349f-48ed-afb4-571043c3a759")) {
#                     Plotly.newPlot(
#                         '923b0b7e-349f-48ed-afb4-571043c3a759',
# ...

# %% [markdown]
# ### Ejercicio para practicar
#
# Queremos entender mejor en que ligas pesa mas la localia, para eso, necesitamos replicar el grafico 3d, sin embargo en vez de mostrar los resultados en totales, los necesitamos en % del total

# %%
df_3d["total_partidos"] = df_3d["local"] + df_3d["empate"] + df_3d["visita"]
df_3d["local%"] = df_3d["local"] / df_3d["total_partidos"]
df_3d["empate%"] = df_3d["empate"] / df_3d["total_partidos"]
df_3d["visita%"] = df_3d["visita"] / df_3d["total_partidos"]

figura_3d = px.scatter_3d(df_3d, x="local%", y="visita%", z="empate%", text = "league")
figura_3d.update_traces(mode = "markers")
# Out:
# <div>
#
#
#             <div id="f0f8eed9-805b-4bc8-80a7-2ea62e2b9456" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f0f8eed9-805b-4bc8-80a7-2ea62e2b9456")) {
#                     Plotly.newPlot(
#                         'f0f8eed9-805b-4bc8-80a7-2ea62e2b9456',
# ...

# %% [markdown]
# ## Histogramas en Plotly
#
# https://plotly.com/python/histograms/
#
# https://plotly.github.io/plotly.py-docs/generated/plotly.graph_objects.Histogram.html

# %%
#Creamos un numpy array random con 100 numeros entre el 1 y el 10
x1_random = np.random.randint(11, size=100)
print(x1_random)

#Creamos dos histogramas
fig1 = go.Figure(data=[go.Histogram(x= x1_random)])
fig2 = go.Figure(data=[go.Histogram(x= x1_random, histnorm='probability')])

fig1.show()
fig2.show()
#Plotly trabaja con una figura general, a la cual se le pueden agregar distintos graficos
# Out:
# [ 6  2  9  4  1  9  5  7  6  6  5  0  8 10  5  0  9  6  3  4  2  5  3  3
#   7  0  4  6  5  3  8  5  5  0 10  9  9  0  3  9  6  6  7 10  0  0 10 10
#   7  6  2  6  6  6  1 10  3  6 10  7  6  8  3  5  5  6  4  8  9  1  7  3
#   7  6  0  0  6  7  4  5  5  0 10  6  3  6  7  2  7  5  0  2  2  6  5  2
#   2  6  1  9]
# <div>
#
#
#             <div id="7896380c-8fde-4fcc-9cd7-d4a287687dd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7896380c-8fde-4fcc-9cd7-d4a287687dd3")) {
#                     Plotly.newPlot(
#                         '7896380c-8fde-4fcc-9cd7-d4a287687dd3',
# ...

# %% [markdown]
# #### Conocemos las variables de una figura en plotly

# %%
x2_random = np.random.randint(11, size=100)

fig = go.Figure()
fig.add_trace(go.Histogram(x= x1_random, histnorm='probability', name="x1"))
fig.add_trace(go.Histogram(x= x2_random, histnorm='probability', name="x2"))

fig.update_layout(title = "Histograma", height = 500, width = 750)
# Out:
# <div>
#
#
#             <div id="5024e209-62fd-4afb-a7cf-754100fca939" class="plotly-graph-div" style="height:500px; width:750px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5024e209-62fd-4afb-a7cf-754100fca939")) {
#                     Plotly.newPlot(
#                         '5024e209-62fd-4afb-a7cf-754100fca939',
# ...

# %% [markdown]
# Que hay detras de las figuras de Plotly?????

# %%
print(fig)
# Out:
# Figure({
#     'data': [{'histnorm': 'probability',
#               'name': 'x1',
#               'type': 'histogram',
#               'x': array([ 0,  4,  7,  1,  7,  8,  2,  5,  6,  0,  6,  2,  4,  1,  6,  5,  1,  1,
#                            6,  0,  9,  9, 10,  8,  0, 10,  7,  3,  0,  4,  9, 10,  7,  0,  6,  4,
#                            6,  1,  9,  5,  1,  1,  9,  0,  1,  2,  7, 10,  3,  4,  6,  0,  7,  4,
#                            4,  4, 10,  6, 10,  8,  7,  3,  9,  3,  0,  4,  9,  6,  0,  9,  9,  5,
#                            6,  7,  2,  8,  6,  2,  6,  7,  5, 10,  7,  4,  6,  1,  6,  4,  8,  2,
#                           10,  5,  8,  4,  7,  8,  2,  0,  3,  9])},
#              {'histnorm': 'probability',
#               'name': 'x2',
#               'type': 'histogram',
#               'x': array([ 5,  1,  9,  6, 10,  5,  9,  3,  2,  2,  7,  3,  2,  5,  2,  8,  2,  5,
# ...

# %% [markdown]
# ### Principales graficos en Plotly
#
# Lineas: https://plotly.com/python/line-charts/
#
# Barras: https://plotly.com/python/bar-charts/
#
# Dispersion: https://plotly.com/python/line-and-scatter/
#
# Dispersion 3D: https://plotly.com/python/3d-scatter-plots/
#
# Histogramas: https://plotly.com/python/histograms/
#
# Cajas: https://plotly.com/python/box-plots/
#
# Radar: https://plotly.com/python/radar-chart/
#
# Violin: https://plotly.com/python/violin/
#
# Heatmap: https://plotly.com/python/heatmaps/
#
# Funnel: https://plotly.com/python/funnel-charts/
#
# Subplots: https://plotly.com/python/subplots/

# %% [markdown]
# ## Ejercicios, ejercicios, ejercicios

# %%
df_matches_goals_winner = pd.read_excel("inputs\\matches_goals_winner.xlsx")

# %%
#Conoce tu df
#winner = 0 --> local | winner = 1 --> empate | winner = 2 --> visita

# %% [markdown]
# #### 1. Grafica la distribucion de la cantidad de partidos segun la cantidad de goles totales que tuvo (histograma)

# %% [markdown]
# #### 2. Utiliza un grafico de cajas para graficar la distribucion de goles por cada liga

# %% [markdown]
# #### Agrupamos la df
#
# pandas groupby: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %%
df_agrupada_ligas = df_matches_goals_winner[["league", "total_goals"]].groupby("league", as_index = False).mean()
df_agrupada_fechas = df_matches_goals_winner[["date", "total_goals"]].groupby("date", as_index = False).mean()

# %% [markdown]
# #### 3. Muestra un grafico de barras con las ligas y la cantidad de goles promedio

# %% [markdown]
# #### 4. Muestra un grafico de lineas con las fechas y la cantidad de goles promedio

# %% [markdown]
# #### 5. Para las 3 ligas con mas partidos en la base, crea un grafico que muestre la correlacion entre la cantidad de goles y el resultado final del partido (ganador local, visita o empate)
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html
#
# https://towardsdatascience.com/better-heatmaps-and-correlation-matrix-plots-in-python-41445d0f2bec
